# %% [markdown]
# # 🚀 NEXUS GPU Cloud Offloader (Google Colab)
# Este notebook permite ejecutar agentes de código pesados (**Ollama**, **DeepSeek-R1**, **Qwen2.5-Coder**, **OpenCode** y **Aider**) en servidores con GPU T4/A100 gratuita de Google, sin consumir recursos de tu computadora.

# %%
# 1. Instalar Ollama en Colab
# !curl -fsSL https://ollama.com/install.sh | sh

# 2. Iniciar servidor Ollama en segundo plano
import subprocess
import time
subprocess.Popen(['ollama', 'serve'])
time.sleep(3)

# 3. Descargar modelos de código optimizados para GPU gratuita
# !ollama pull qwen2.5-coder:7b
# !ollama pull deepseek-r1:7b
# Out:
# Running cells with 'Python 3.14.4' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/Dell/AppData/Local/Python/pythoncore-3.14-64/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# 4. Instalar OpenCode y Aider en el entorno Cloud
# !npm install -g opencode-ai
# %pip install aider-chat requests duckdb

# %%
# 5. Clonar tu repositorio NEXUS y empezar a trabajar con el Agente
# !git clone https://github.com/israel2811/files-mentioned-by-the-user-texto.git
# %cd files-mentioned-by-the-user-texto
# !aider --model ollama/qwen2.5-coder:7b
